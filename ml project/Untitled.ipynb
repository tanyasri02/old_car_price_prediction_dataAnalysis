# %% [markdown]
# # Introduction : About project and dataset

# %%
# Load the pandas,numpy,matplotlib and other required libraries with an import statement
import pandas as pd                # importing pandas as pd
import numpy as np                 # importing numpy as np    
import matplotlib.pyplot as plt    #importing matplotlib as plt
import seaborn as sns              #importing seaborn as sns
# %matplotlib inline
import datetime
from dateutil.relativedelta import relativedelta
from datetime import date
from datetime import time

# %%
# Load the dataset into a pandas dataframe
df = pd.read_csv('car_dataset.csv', sep=',',low_memory=False, encoding ='latin-1')

# %%
# Display the first ten lines of the dataset
df.head(5)
# Out:
#    S_number                              Name    Location  Year  \
# 0         0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1         1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2         2                      Honda Jazz V     Chennai  2011
# 3         3                 Maruti Ertiga VDI     Chennai  2012
# 4         4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage(kmpl)  \
# 0              72000       CNG       Manual      First          26.60
# 1              41000    Diesel       Manual      First          19.67
# 2              46000    Petrol       Manual      First          18.20
# 3              87000    Diesel       Manual      First          20.77
# 4              40670    Diesel    Automatic     Second          15.20
#
#    Engine(CC) Power(bhp)  Seats  New_Price  Price paint_color         type  \
# 0       998.0      58.16    5.0        NaN   1.75        blue        other
# ...

# %%
# information about keys or attributes
df.keys()
#S_number is serial number
# Out:
# Index(['S_number', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage(kmpl)',
#        'Engine(CC)', 'Power(bhp)', 'Seats', 'New_Price', 'Price',
#        'paint_color', 'type', 'condition'],
#       dtype='object')

# %%
# Display the last few lines of the dataset
df.tail(10)
# Out:
#       S_number                                 Name    Location  Year  \
# 6009      6009                  Toyota Camry Hybrid      Mumbai  2015
# 6010      6010                 Honda Brio 1.2 VX MT       Delhi  2013
# 6011      6011              Skoda Superb 3.6 V6 FSI   Hyderabad  2009
# 6012      6012  Toyota Innova 2.5 V Diesel 7-seater  Coimbatore  2011
# 6013      6013                Honda Amaze VX i-DTEC  Coimbatore  2015
# 6014      6014                     Maruti Swift VDI       Delhi  2014
# 6015      6015             Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016      6016                Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017      6017                   Maruti Wagon R VXI     Kolkata  2013
# 6018      6018                Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage(kmpl)  \
# 6009              33500    Petrol    Automatic      First          19.16
# ...

# %% [markdown]
# ## Information related to dataset

# %%
# Display summary of the dataframe including the data types of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S_number           6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage(kmpl)      6017 non-null   float64
#  9   Engine(CC)         5983 non-null   float64
#  10  Power(bhp)         5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
#  14  paint_color        3895 non-null   object
#  15  type               4586 non-null   object
# ...

# %%
# Display summary of the dataframe including the data types of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S_number           6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage(kmpl)      6017 non-null   float64
#  9   Engine(CC)         5983 non-null   float64
#  10  Power(bhp)         5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
#  14  paint_color        3895 non-null   object
#  15  type               4586 non-null   object
# ...

# %%
#Frequency Counts of name
df['Name'].value_counts()
# Out:
# Mahindra XUV500 W8 2WD               49
# Maruti Swift VDI                     45
# Honda City 1.5 S MT                  34
# Maruti Swift Dzire VDI               34
# Maruti Swift VDI BSIV                31
#                                      ..
# Tata Tiago 1.2 Revotron XT Option     1
# Renault Scala RxL                     1
# Skoda Octavia Ambition 1.8 TSI AT     1
# Nissan Micra Diesel                   1
# Tata Nano Cx BSIV                     1
# Name: Name, Length: 1876, dtype: int64

# %%
#Frequency Counts of location
df['Location'].value_counts()
# Out:
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: Location, dtype: int64

# %%
#Frequency Counts of year
df['Year'].value_counts()
# Out:
# 2014    797
# 2015    744
# 2016    741
# 2013    649
# 2017    587
# 2012    580
# 2011    466
# 2010    342
# 2018    298
# 2009    198
# 2008    174
# 2007    125
# 2019    102
# 2006     78
# 2005     57
# 2004     31
# 2003     17
# 2002     15
# 2001      8
# 1998      4
# 2000      4
# 1999      2
# Name: Year, dtype: int64

# %%
#Frequency Counts of km_driven
df['Kilometers_Driven'].value_counts()
# Out:
# 60000    82
# 45000    70
# 65000    68
# 50000    61
# 70000    60
#          ..
# 50446     1
# 54540     1
# 70920     1
# 75014     1
# 83969     1
# Name: Kilometers_Driven, Length: 3093, dtype: int64

# %%
#Frequency Counts of fuel type
df['Fuel_Type'].value_counts()
# Out:
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
#Frequency Counts of transmission
df['Transmission'].value_counts()
# Out:
# Manual       4299
# Automatic    1720
# Name: Transmission, dtype: int64

# %%
#Frequency Counts of owner_type
df['Owner_Type'].value_counts()
# Out:
# First             4929
# Second             968
# Third              113
# Fourth & Above       9
# Name: Owner_Type, dtype: int64

# %%
#Frequency Counts of mileage(in kmpl)
df['Mileage(kmpl)'].value_counts()
# Out:
# 17.00    173
# 18.90    172
# 18.60    119
# 20.36     88
# 21.10     87
#         ...
# 13.29      1
# 12.97      1
# 23.01      1
# 15.11      1
# 14.45      1
# Name: Mileage(kmpl), Length: 430, dtype: int64

# %%
#Frequency Counts of engine
df['Engine(CC)'].value_counts()
# Out:
# 1197.0    606
# 1248.0    512
# 1498.0    304
# 998.0     259
# 2179.0    240
#          ...
# 2149.0      1
# 3197.0      1
# 2694.0      1
# 970.0       1
# 2999.0      1
# Name: Engine(CC), Length: 146, dtype: int64

# %%
#Frequency Counts of power
df['Power(bhp)'].value_counts()
# Out:
# 74        235
# 98.6      131
# 73.9      125
# 140       123
# 88.5      112
#          ...
# 181.43      1
# 550         1
# 98.79       1
# 246.74      1
# 226.6       1
# Name: Power(bhp), Length: 370, dtype: int64

# %%
#Frequency Counts of seats
df['Seats'].value_counts()
# Out:
# 5.0     5014
# 7.0      674
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64

# %%
#Frequency Counts of new_prices
df['New_Price'].value_counts()
# Out:
# 63.71 Lakh    6
# 4.78 Lakh     6
# 95.13 Lakh    6
# 44.28 Lakh    5
# 11.67 Lakh    5
#              ..
# 17.21 Lakh    1
# 38.11 Lakh    1
# 39.22 Lakh    1
# 8.05 Lakh     1
# 6.74 Lakh     1
# Name: New_Price, Length: 540, dtype: int64

# %%
#Frequency Counts of prices
df['Price'].value_counts()
# Out:
# 4.50     88
# 5.50     84
# 3.50     82
# 4.25     73
# 3.25     71
#          ..
# 11.96     1
# 5.76      1
# 24.99     1
# 42.75     1
# 16.42     1
# Name: Price, Length: 1373, dtype: int64

# %%
#Frequency Counts of paint_color
df['paint_color'].value_counts()
# Out:
# white     964
# black     800
# silver    658
# blue      386
# red       372
# grey      362
# brown     110
# green      88
# custom     80
# orange     36
# yellow     31
# purple      8
# Name: paint_color, dtype: int64

# %%
#Frequency Counts of type
df['type'].value_counts()
# Out:
# sedan          1194
# SUV            1001
# pickup          673
# truck           545
# other           317
# coupe           295
# hatchback       196
# wagon           128
# convertible      88
# van              86
# mini-van         55
# offroad           5
# bus               3
# Name: type, dtype: int64

# %%
#Frequency Counts of condition
df['condition'].value_counts()
# Out:
# good         1782
# excellent    1326
# like new      251
# fair           79
# new            11
# salvage         5
# Name: condition, dtype: int64

# %%
# Find the number of non-NA/null value across each column
df.count()
# Out:
# S_number             6019
# Name                 6019
# Location             6019
# Year                 6019
# Kilometers_Driven    6019
# Fuel_Type            6019
# Transmission         6019
# Owner_Type           6019
# Mileage(kmpl)        6017
# Engine(CC)           5983
# Power(bhp)           5983
# Seats                5977
# New_Price             824
# Price                6019
# paint_color          3895
# type                 4586
# condition            3454
# dtype: int64

# %%
# Display the column names
df.columns
# Out:
# Index(['S_number', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage(kmpl)',
#        'Engine(CC)', 'Power(bhp)', 'Seats', 'New_Price', 'Price',
#        'paint_color', 'type', 'condition'],
#       dtype='object')

# %%
# Find the number of Not available values in each column 
autos_missing_values = df.isnull().sum()
autos_missing_values
# Out:
# S_number                0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage(kmpl)           2
# Engine(CC)             36
# Power(bhp)             36
# Seats                  42
# New_Price            5195
# Price                   0
# paint_color          2124
# type                 1433
# condition            2565
# dtype: int64

# %%
# Find the number of rows and columns in the dataset
# Check the dataset size
df.shape
# Out:
# (6019, 17)

# %%
# Descriptive or Summary statistics of numeric columns
df.describe()
# Out:
#           S_number         Year  Kilometers_Driven  Mileage(kmpl)  \
# count  6019.000000  6019.000000       6.019000e+03    6017.000000
# mean   3009.000000  2013.358199       5.873838e+04      18.138744
# std    1737.679967     3.269742       9.126884e+04       4.567998
# min       0.000000  1998.000000       1.710000e+02       0.000000
# 25%    1504.500000  2011.000000       3.400000e+04      15.170000
# 50%    3009.000000  2014.000000       5.300000e+04      18.150000
# 75%    4513.500000  2016.000000       7.300000e+04      21.100000
# max    6018.000000  2019.000000       6.500000e+06      33.540000
#
#         Engine(CC)        Seats        Price
# count  5983.000000  5977.000000  6019.000000
# mean   1621.276450     5.278735     9.479468
# std     601.355233     0.808840    11.187917
# min      72.000000     0.000000     0.440000
# 25%    1198.000000     5.000000     3.500000
# 50%    1493.000000     5.000000     5.640000
# 75%    1984.000000     5.000000     9.950000
# ...

# %%
# Summary statistics of character or non-numeric columns
df.describe(include=['object'])
# Out:
#                           Name Location Fuel_Type Transmission Owner_Type  \
# count                     6019     6019      6019         6019       6019
# unique                    1876       11         5            2          4
# top     Mahindra XUV500 W8 2WD   Mumbai    Diesel       Manual      First
# freq                        49      790      3205         4299       4929
#
#        Power(bhp)   New_Price paint_color   type condition
# count        5983         824        3895   4586      3454
# unique        370         540          12     13         6
# top            74  63.71 Lakh       white  sedan      good
# freq          235           6         964   1194      1782

# %% [markdown]
# # missing values

# %%
# https://stackoverflow.com/questions/49575897/cant-replace-0-to-nan-in-python-using-pandas
# Convert zeros(0.0) to missing values - Replace 0 with null
df.replace(0.0, np.nan, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S_number           6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage(kmpl)      5952 non-null   float64
#  9   Engine(CC)         5983 non-null   float64
#  10  Power(bhp)         5983 non-null   object
#  11  Seats              5976 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
#  14  paint_color        3895 non-null   object
#  15  type               4586 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# S_number                0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage(kmpl)          67
# Engine(CC)             36
# Power(bhp)             36
# Seats                  43
# New_Price            5195
# Price                   0
# paint_color          2124
# type                 1433
# condition            2565
# dtype: int64

# %%
df.head(10)
# Out:
#    S_number                                 Name    Location  Year  \
# 0         0               Maruti Wagon R LXI CNG      Mumbai  2010
# 1         1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2         2                         Honda Jazz V     Chennai  2011
# 3         3                    Maruti Ertiga VDI     Chennai  2012
# 4         4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5         5      Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6         6               Nissan Micra Diesel XV      Jaipur  2013
# 7         7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8         8  Volkswagen Vento Diesel Comfortline        Pune  2013
# 9         9       Tata Indica Vista Quadrajet LS     Chennai  2012
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage(kmpl)  \
# 0              72000       CNG       Manual      First          26.60
# 1              41000    Diesel       Manual      First          19.67
# ...

# %%
# datatype of elements
df.dtypes
# Out:
# S_number               int64
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage(kmpl)        float64
# Engine(CC)           float64
# Power(bhp)            object
# Seats                float64
# New_Price             object
# Price                float64
# paint_color           object
# type                  object
# condition             object
# dtype: object

# %% [markdown]
# ## Changing datatype as per requirement

# %%
autos_df2 = df.copy()
autos_df2.head()
# Out:
#    S_number                              Name    Location  Year  \
# 0         0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1         1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2         2                      Honda Jazz V     Chennai  2011
# 3         3                 Maruti Ertiga VDI     Chennai  2012
# 4         4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage(kmpl)  \
# 0              72000       CNG       Manual      First          26.60
# 1              41000    Diesel       Manual      First          19.67
# 2              46000    Petrol       Manual      First          18.20
# 3              87000    Diesel       Manual      First          20.77
# 4              40670    Diesel    Automatic     Second          15.20
#
#    Engine(CC) Power(bhp)  Seats  New_Price  Price paint_color         type  \
# 0       998.0      58.16    5.0        NaN   1.75        blue        other
# ...

# %%
# Convert Car Seller Type from string to categorical
autos_df2['Location'] = autos_df2.Location.astype('category')

# %%
autos_df2.dtypes
# Out:
# S_number                      int64
# Name                         object
# Location                   category
# Year                 datetime64[ns]
# Kilometers_Driven             int64
# Fuel_Type                    object
# Transmission                 object
# Owner_Type                   object
# Mileage(kmpl)               float64
# Engine(CC)                  float64
# Power(bhp)                   object
# Seats                       float64
# New_Price                    object
# Price                       float64
# paint_color                  object
# type                         object
# condition                    object
# dtype: object

# %%
autos_df2.head()
# Out:
#    S_number                              Name    Location  Year  \
# 0         0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1         1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2         2                      Honda Jazz V     Chennai  2011
# 3         3                 Maruti Ertiga VDI     Chennai  2012
# 4         4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage(kmpl)  \
# 0              72000       CNG       Manual      First          26.60
# 1              41000    Diesel       Manual      First          19.67
# 2              46000    Petrol       Manual      First          18.20
# 3              87000    Diesel       Manual      First          20.77
# 4              40670    Diesel    Automatic     Second          15.20
#
#    Engine(CC) Power(bhp)  Seats  New_Price  Price paint_color         type  \
# 0       998.0      58.16    5.0        NaN   1.75        blue        other
# ...

# %%
# https://stackoverflow.com/questions/17134716/convert-dataframe-column-type-from-string-to-datetime
# Change year column data type from string to year
# with date specified in American date format
autos_df2['Year'] = pd.to_datetime(autos_df2['Year'])
autos_df2.dtypes
# Out:
# S_number                      int64
# Name                         object
# Location                   category
# Year                 datetime64[ns]
# Kilometers_Driven             int64
# Fuel_Type                    object
# Transmission                 object
# Owner_Type                   object
# Mileage(kmpl)               float64
# Engine(CC)                  float64
# Power(bhp)                   object
# Seats                       float64
# New_Price                    object
# Price                       float64
# paint_color                  object
# type                         object
# condition                    object
# dtype: object

# %%
autos_df2.isnull().sum()
# Out:
# S_number                0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage(kmpl)          67
# Engine(CC)             36
# Power(bhp)             36
# Seats                  43
# New_Price            5195
# Price                   0
# paint_color          2124
# type                 1433
# condition            2565
# dtype: int64

# %% [markdown]
# ## Dealing with Missing Values

# %%
#Summarize the number of rows and columns in the dataset
print(autos_df2.shape)
# Out:
# (6019, 17)

# %%
# Drop the rows where all elements are missing
autos_clean_df = autos_df2.dropna(how ='all')

#Summarize the number of rows and columns in the dataset
print(autos_clean_df.shape)
# Out:
# (6019, 17)

# %%
# Drop rows that contain less than five observations
autos_clean_df = autos_clean_df.dropna(thresh=5)

#Summarize the number of rows and columns in the dataset
print(autos_clean_df.shape)
# Out:
# (6019, 17)

# %%
print(autos_clean_df.shape)
# Out:
# (6019, 16)

# %%
autos_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6019 entries, 0 to 6018
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S_number           6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   category
#  3   Year               6019 non-null   datetime64[ns]
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage(kmpl)      5952 non-null   float64
#  9   Engine(CC)         5983 non-null   float64
#  10  Power(bhp)         5983 non-null   object
#  11  Seats              5976 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
#  14  paint_color        3895 non-null   object
# ...

# %%
autos_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6019 entries, 0 to 6018
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S_number           6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   category
#  3   Year               6019 non-null   datetime64[ns]
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage(kmpl)      5952 non-null   float64
#  9   Engine(CC)         5983 non-null   float64
#  10  Power(bhp)         5983 non-null   object
#  11  Seats              5976 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
#  14  paint_color        3895 non-null   object
# ...

# %%
autos_clean_df.head(10)
# Out:
#    S_number                                 Name    Location  \
# 0         0               Maruti Wagon R LXI CNG      Mumbai
# 1         1     Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                         Honda Jazz V     Chennai
# 3         3                    Maruti Ertiga VDI     Chennai
# 4         4      Audi A4 New 2.0 TDI Multitronic  Coimbatore
# 5         5      Hyundai EON LPG Era Plus Option   Hyderabad
# 6         6               Nissan Micra Diesel XV      Jaipur
# 7         7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai
# 8         8  Volkswagen Vento Diesel Comfortline        Pune
# 9         9       Tata Indica Vista Quadrajet LS     Chennai
#
#                            Year  Kilometers_Driven Fuel_Type Transmission  \
# 0 1970-01-01 00:00:00.000002010              72000       CNG       Manual
# 1 1970-01-01 00:00:00.000002015              41000    Diesel       Manual
# ...

# %% [markdown]
# ## Cleaning up Erronous Values - Outliers Removal

# %%
#Summary statistics for Car_Engine_Power
print(autos_clean_df['Power(bhp)'].describe())
# Out:
# count     5983
# unique     370
# top         74
# freq       235
# Name: Power(bhp), dtype: object

# %%
print(autos_clean_df['Price'].describe())
# Out:
# count    6019.000000
# mean        9.479468
# std        11.187917
# min         0.440000
# 25%         3.500000
# 50%         5.640000
# 75%         9.950000
# max       160.000000
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(180,122))
sns.countplot(x= 'Price', data = autos_clean_df)
#plt.savefig('Vehicle Type Frequency plot.pdf')
